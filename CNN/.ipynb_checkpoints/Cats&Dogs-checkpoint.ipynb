# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Input,Flatten
from tensorflow import keras
from keras.utils import image_dataset_from_directory
from sklearn.metrics import classification_report,confusion_matrix
from tensorflow.keras.regularizers import l2
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/mnt/c/Users/91940/projects/dl/Deep Learning/Week3'

# %%
train_ds,val_ds=image_dataset_from_directory(
    directory='/mnt/c/Users/91940/projects/dl/Deep Learning/Week3/cats_and_dogs_filtered/cats_and_dogs_filtered/train',batch_size=32,labels='inferred',label_mode='categorical',validation_split=0.2,seed=50,image_size=(256,256),subset='both'
)
# Out:
# Found 2000 files belonging to 2 classes.
# Using 1600 files for training.
# Using 400 files for validation.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733615211.061497    1149 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1733615211.353708    1149 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1733615211.353758    1149 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1733615211.357809    1149 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# ...

# %%
test_ds=image_dataset_from_directory(
    directory='/mnt/c/Users/91940/projects/dl/Deep Learning/Week3/cats_and_dogs_filtered/cats_and_dogs_filtered/validation',
    batch_size=32,
    labels='inferred',
    label_mode='categorical',
    seed=50,image_size=(256,256)
)
# Out:
# Found 1000 files belonging to 2 classes.

# %%
cnn=Sequential([
    Input(shape=(256,256,3)),
    keras.layers.Rescaling(1./255),
    keras.layers.Conv2D(64,kernel_size=(5,5),activation='relu',strides=(2,2)),
    keras.layers.MaxPooling2D(strides=(2,2)),
    keras.layers.Conv2D(32,kernel_size=(5,5),activation='relu',strides=(1,1)),
    keras.layers.MaxPooling2D(strides=(2,2)),
    keras.layers.Conv2D(32,kernel_size=(3,3),activation='relu',strides=(1,1)),
          keras.layers.Flatten(),
          keras.layers.Dense(100,activation='relu',kernel_regularizer=l2()),
          keras.layers.Dropout(0.5),
          keras.layers.Dense(2,activation='softmax')
])

# %%
cnn.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
his=cnn.fit(train_ds,validation_data=val_ds,epochs=30)
# Out:
# Epoch 1/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.4767 - loss: 1.5172 - val_accuracy: 0.5075 - val_loss: 0.7466
# Epoch 2/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.4955 - loss: 0.7259 - val_accuracy: 0.5100 - val_loss: 0.6988
# Epoch 3/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.4964 - loss: 0.6974 - val_accuracy: 0.4925 - val_loss: 0.6950
# Epoch 4/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.4981 - loss: 0.6962 - val_accuracy: 0.4925 - val_loss: 0.6950
# Epoch 5/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5049 - loss: 0.6946 - val_accuracy: 0.4925 - val_loss: 0.6934
# Epoch 6/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5084 - loss: 0.6932 - val_accuracy: 0.4925 - val_loss: 0.6932
# Epoch 7/30
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.4982 - loss: 0.6931 - val_accuracy: 0.4925 - val_loss: 0.6932
# Epoch 8/30
# ...

# %%
plt.plot(his.history['loss'],label='Training Loss')
plt.plot(his.history['val_loss'],label='Validation Loss')
plt.legend()
plt.show()

plt.plot(his.history['accuracy'],label='training Accuracy')
plt.plot(his.history['val_accuracy'],label='Validation Accuracy')
plt.legend()
plt.show()
